# %%
# Código para dataset de café con datos de aroma y con pipelines
# Luz Adriana Plazas Pemberthy 2190651

# %%
#instalación de librerías no contenidas en colab
# !pip install mglearn
# import mglearn

# %% [markdown]
# **Cargar las librerías básicas y el dataset al programa**
#
# ---

# %%
#importar librerías basicas
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
#importar métodos de preprocesamiento
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import RobustScaler
import statsmodels.formula.api as sm
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#subir archivo
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-58ceb849-a04a-4295-ab00-7a3fb7ea8b2f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-58ceb849-a04a-4295-ab00-7a3fb7ea8b2f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving df_aroma.csv to df_aroma.csv

# %%
# Cargar el dataset
Coffee = pd.read_csv("df_aroma.csv", sep=',')
# Convert string target vector to integer

X = Coffee.loc[:,'Muestras':'Phad']
y = Coffee.loc[:,'aroma']
#Revisar el tamaño del dataset cargado
print ('X')
print (X.shape)
print ('y')
print (y.shape)
# Out:
# X
# (16, 51)
# y
# (16,)

# %%
# Se realiza la separación del dataset
# B Separar en train y test
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=1)
# print("per-feature minimum before scaling:\n {}".format(X_train.min(axis=0)))
# print("per-feature maximum before scaling:\n {}".format(X_train.max(axis=0)))
# print("target minimum before scaling:\n {}".format(y_train.min(axis=0)))
# print("target maximum before scaling:\n {}".format(y_train.max(axis=0)))

# %% [markdown]
# PREPROCESAMIENTO

# %% [markdown]
# Pruebas iniciales con los modelos básicos de regresión

# %%
###pruebas de regresión  básica
# Regresion lineal LS
from sklearn.linear_model import LinearRegression
lrLS = LinearRegression()
lrLS.fit(X_train, y_train)
print("Train set score linear regression: {:.2f}".format(lrLS.score(X_train, y_train)))
print("Test set score linear regression: {:.2f}".format(lrLS.score(X_test, y_test)))
# Out:
# Train set score linear regression: 1.00
# Test set score linear regression: 0.94

# %%
 Train_set=X_train
 Train_set['aroma']=y_train
#  Modelo=sm.ols(formula='aroma ~ Muestras + Phme + Pha + TDSa + Phv + Phdif + Phd + Phmax + Alcohola + Phmo + Phf + Co2max + Co2dif + Co2d + TDSmind + Alcoholmax + Alcoholdifd + Co2v + Temp1dif + Temp1max + Alcoholdif + Alcoholmaxd + Temp1maxd + Temp1a + Co2maxd + Temp1me + Co2difd + Temp2dif + Alcoholi + Alcoholmin + Phdd + Phvd + TDSf + Temp2f + TDSmaxd + Temp2min + Alcoholf + TDSvd + TDSdifd + TDSdd + Temp2ad + Alcoholv + Alcohold + Alcoholad + TDSv + TDSad + Co2f + Temp1ad + TDSd + Co2ad + Phad', data= Train_set)
#  Modelo=sm.ols(formula='aroma ~ Muestras + Phme + Pha + TDSa + Phv + Phdif + Phd + Phmax + Alcohola + Phmo + Temp2ad + Alcoholv + Alcohold + Alcoholad + TDSv + TDSad + Co2f + Temp1ad + TDSd + Co2ad + Phad', data= Train_set)
 Modelo=sm.ols(formula='aroma ~ Muestras + Phme +  Co2ad + Alcoholad + TDSd + Temp1ad +Temp2ad', data= Train_set)
#  Modelo=sm.ols(formula='aroma ~ Muestras + Pha +  Co2ad + Alcoholad + TDSd + Temp1ad +Temp2ad', data= Train_set)
 Fitted=Modelo.fit()
 print(Fitted.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  aroma   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.987
# Method:                 Least Squares   F-statistic:                     117.1
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):           0.000184
# Time:                        20:05:16   Log-Likelihood:                 29.057
# No. Observations:                  12   AIC:                            -42.11
# Df Residuals:                       4   BIC:                            -38.23
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.2010      0.584     12.339      0.000       5.581       8.821
# Muestras       0.0002   3.31e-05      5.650      0.005    9.51e-05       0.000
# Phme          -0.0002      0.000     -0.508      0.638      -0.001       0.001
# Co2ad         -6.9825      4.534     -1.540      0.198     -19.571       5.606
# Alcoholad      3.3095      1.294      2.558      0.063      -0.282       6.901
# TDSd          -0.0031      0.004     -0.838      0.449      -0.013       0.007
# Temp1ad     -109.0776    168.850     -0.646      0.553    -577.882     359.726
# Temp2ad      -92.8057    122.473     -0.758      0.491    -432.844     247.233
# ==============================================================================
# Omnibus:                        1.502   Durbin-Watson:                   1.713
# Prob(Omnibus):                  0.472   Jarque-Bera (JB):                0.230
# Skew:                          -0.304   Prob(JB):                        0.891
# Kurtosis:                       3.302   Cond. No.                     6.97e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.97e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.7/dist-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   "anyway, n=%i" % int(n))

# %%
Prediccion=Fitted.predict(X_test) #guardar la predicción y luego sacar el error
print('\n\n MSE:\t',mean_squared_error(y_test,Prediccion))
print('\n MAE:\t',mean_absolute_error(y_test,Prediccion))
print('\n R2 Score test:\t',r2_score(y_test,Prediccion),'\n')
# Out:
#  MSE:	 0.013265670576895159
#
#  MAE:	 0.09489180270795994
#
#  R2 Score test:	 0.8758767665319751

# %%
Coffee = pd.read_csv("df_aroma.csv", sep=',')
X = Coffee.loc[:,'Muestras':'Phad']
y = Coffee.loc[:,'aroma']

X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=1)

# X_train=X.loc[[0,1,2,4,5,6,8,9,10,12,13,14]]
# X_test=X.loc[[3,7,11,15]]
# y_train=y.loc[[0,1,2,4,5,6,8,9,10,12,13,14]]
# y_test=y.loc[[3,7,11,15]]

col_sec=['Muestras' , 'Phme' ,  'Co2ad' , 'Alcoholad' , 'TDSd' , 'Temp1ad' , 'Temp2ad']
X_train=X_train[col_sec]
X_test=X_test[col_sec]
# X_test
# y_test
#X_train

# %%
lrLS = LinearRegression()
lrLS.fit(X_train, y_train)
print("Train set score linear regression: {:.2f}".format(lrLS.score(X_train, y_train)))
print("Test set score linear regression: {:.2f}".format(lrLS.score(X_test, y_test)))
# Out:
# Train set score linear regression: 1.00
# Test set score linear regression: 0.88

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline

# %%
# regresión lineal con Ridge
from sklearn.linear_model import Ridge
ridge = Ridge().fit(X_train, y_train)
print("Training set score Ridge regression: {:.2f}".format(ridge.score(X_train, y_train)))
print("Test set score Ridge regression: {:.2f}".format(ridge.score(X_test, y_test)))
#Optimizacion de hiperparámetros con Pipeline and GridSearch
# param_grid = {'alpha': [0.0001,0.001, 0.01, 0.1, 1, 10, 100, 1000]}
param_grid = {'ridge__alpha': [0.0001,0.001, 0.01, 0.1, 1, 10, 100, 1000]}
print ("\n")
# MINMAX scaler
pipe = make_pipeline(MinMaxScaler(), Ridge())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("RIDGE MinMax Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Standar scaler
pipe = make_pipeline(StandardScaler(), Ridge())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("RIDGE STANDAR Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Normalizer scaler
pipe = make_pipeline(Normalizer(), Ridge())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("RIDGE Normailzer Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")


# Robust scaler
pipe = make_pipeline(RobustScaler(), Ridge())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("RIDGE Robust Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
# Out:
# Training set score Ridge regression: 0.97
# Test set score Ridge regression: 0.96
#
#
# RIDGE MinMax Score without poly features: 0.95
# Best cross-validation accuracy: 0.74
# Best parameters: {'ridge__alpha': 0.1}
#
#
# RIDGE STANDAR Score without poly features: 0.94
# Best cross-validation accuracy: 0.74
# Best parameters: {'ridge__alpha': 1}
#
#
# RIDGE Normailzer Score without poly features: 0.84
# Best cross-validation accuracy: -0.41
# Best parameters: {'ridge__alpha': 0.01}
#
#
# RIDGE Robust Score without poly features: 0.94
# Best cross-validation accuracy: 0.77
# Best parameters: {'ridge__alpha': 1}

# %%
#Regresión lineal con lasso
from sklearn.linear_model import Lasso
lasso = Lasso(max_iter=10000).fit(X_train, y_train)
print("Training set score Lasso Regression: {:.2f}".format(lasso.score(X_train, y_train)))
print("Test set score Lasso Regression: {:.2f}".format(lasso.score(X_test, y_test)))
print("Number of features used Lasso Regression:", np.sum(lasso.coef_ != 0))

#Optimizacion de hiperparámetros con Pipeline and GridSearch

param_grid = {'lasso__alpha': [0.0001,0.001, 0.01, 0.1, 1, 10, 100, 1000], 'lasso__tol': [0.00001,0.0001,0.001]}
# MINMAX scaler
pipe = make_pipeline(MinMaxScaler(), Lasso())
pipe.get_params().keys()
# pipe = make_pipeline(MinMaxScaler(), Lasso())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("Lasso MinMax Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Standar scaler
pipe = make_pipeline(StandardScaler(), Lasso())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("Lasso STANDAR Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Normalizer scaler
pipe = make_pipeline(Normalizer(), Lasso())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("Lasso Normailzer Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")


# Robust scaler
pipe = make_pipeline(RobustScaler(), Lasso())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("Lasso Robust Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")
# Out:
# Training set score Lasso Regression: 0.95
# Test set score Lasso Regression: 0.96
# Number of features used Lasso Regression: 2
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.080e-05, tolerance: 9.239e-06
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.124e-05, tolerance: 6.289e-06
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.272e-05, tolerance: 9.440e-06
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.366e-05, tolerance: 9.440e-06
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# Lasso MinMax Score without poly features: 0.84
# Best cross-validation accuracy: 0.75
# Best parameters: {'lasso__alpha': 0.001, 'lasso__tol': 0.001}
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.020e-03, tolerance: 9.239e-06
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.535e-04, tolerance: 6.289e-06
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.619e-05, tolerance: 9.440e-06
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.684e-05, tolerance: 9.440e-06
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.020e-03, tolerance: 9.239e-05
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.535e-04, tolerance: 6.289e-05
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.020e-03, tolerance: 9.239e-04
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# Lasso STANDAR Score without poly features: 0.82
# Best cross-validation accuracy: 0.75
# Best parameters: {'lasso__alpha': 0.001, 'lasso__tol': 0.001}
#
#
# Lasso Normailzer Score without poly features: 0.89
# Best cross-validation accuracy: -0.60
# Best parameters: {'lasso__alpha': 0.001, 'lasso__tol': 1e-05}
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.723e-04, tolerance: 9.239e-06
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.113e-04, tolerance: 6.289e-06
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.487e-05, tolerance: 9.440e-06
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.519e-05, tolerance: 1.021e-05
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.723e-04, tolerance: 9.239e-05
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.113e-04, tolerance: 6.289e-05
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# Lasso Robust Score without poly features: 0.87
# Best cross-validation accuracy: 0.84
# Best parameters: {'lasso__alpha': 0.01, 'lasso__tol': 1e-05}

# %%
#Bayesian Ridge Regression
from sklearn import linear_model
Bay= linear_model.BayesianRidge()
Bay.fit(X_train, y_train)
print("Training set score Bayesian Ridge Regression: {:.2f}".format(Bay.score(X_train, y_train)))
print("Test set score Bayesian Ridge Regression: {:.2f}".format(Bay.score(X_test, y_test)))
print ("\n")
#print ("Los modelos básicos han arrojado malos resultados")
#Optimizacion de hiperparámetros con Pipeline and GridSearch

param_grid = {'bayesianridge__alpha_1': [1e-2, 0.1, 1, 10, 100, 1000], 'bayesianridge__tol': [0.00001,0.0001,0.001]}
# MINMAX scaler
pipe = make_pipeline(MinMaxScaler(), linear_model.BayesianRidge())
pipe.get_params().keys()
# pipe = make_pipeline(MinMaxScaler(), Lasso())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("BayesianRidge MinMax Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Standar scaler
pipe = make_pipeline(StandardScaler(), linear_model.BayesianRidge())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("BayesianRidge STANDAR Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Normalizer scaler
pipe = make_pipeline(Normalizer(), linear_model.BayesianRidge())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("BayesianRidge Normailzer Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")


# Robust scaler
pipe = make_pipeline(RobustScaler(), linear_model.BayesianRidge())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("BayesianRidge Robust Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")
# Out:
# Training set score Bayesian Ridge Regression: 0.96
# Test set score Bayesian Ridge Regression: 0.96
#
#
# BayesianRidge MinMax Score without poly features: 0.86
# Best cross-validation accuracy: 0.64
# Best parameters: {'bayesianridge__alpha_1': 0.01, 'bayesianridge__tol': 0.001}
#
#
# BayesianRidge STANDAR Score without poly features: 0.86
# Best cross-validation accuracy: 0.64
# Best parameters: {'bayesianridge__alpha_1': 0.01, 'bayesianridge__tol': 0.001}
#
#
# BayesianRidge Normailzer Score without poly features: 0.90
# Best cross-validation accuracy: 0.86
# Best parameters: {'bayesianridge__alpha_1': 10, 'bayesianridge__tol': 1e-05}
#
#
# BayesianRidge Robust Score without poly features: 0.86
# Best cross-validation accuracy: 0.66
# Best parameters: {'bayesianridge__alpha_1': 0.01, 'bayesianridge__tol': 0.001}

# %%
#Stochastic Gradient Descent SGDRegressor 
from sklearn.linear_model import SGDRegressor
SGDreg = SGDRegressor(max_iter=1000, tol=1e-3)
SGDreg.fit (X_train, y_train)
print("Training set score SGD Regressor: {:.2f}".format(SGDreg.score(X_train, y_train)))
print("Test set score SGD Regressor: {:.2f}".format(SGDreg.score(X_test, y_test)))

#Optimizacion de hiperparámetros con Pipeline and GridSearch

param_grid = {'sgdregressor__alpha': [0.0001, 0.001, 0.01, 0.1, 10, 100],
              'sgdregressor__tol': [0.0001,0.001, 0.01, 0.1, 1, 10, 100,1000]}

# pipe = make_pipeline(MinMaxScaler(), SGDRegressor(max_iter=10000))
# pipe.get_params().keys()

# MINMAX scaler
pipe = make_pipeline(MinMaxScaler(), SGDRegressor(max_iter=10000))
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("SGDRegressor MinMax Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Standar scaler
pipe = make_pipeline(StandardScaler(), SGDRegressor(max_iter=10000))
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("SGDRegressor STANDAR Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Normalizer scaler
pipe = make_pipeline(Normalizer(), SGDRegressor(max_iter=10000))
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("SGDRegressor Normailzer Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")


# Robust scaler
pipe = make_pipeline(RobustScaler(), SGDRegressor(max_iter=10000))
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("SGDRegressor Robust Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
# print ("\n")
# Out:
# Training set score SGD Regressor: -4091168246967302861875171326689280.00
# Test set score SGD Regressor: -2474247148035264140568964659937280.00
# SGDRegressor MinMax Score without poly features: 0.08
# Best cross-validation accuracy: -3.14
# Best parameters: {'sgdregressor__alpha': 10, 'sgdregressor__tol': 0.0001}
#
#
# SGDRegressor STANDAR Score without poly features: 0.86
# Best cross-validation accuracy: 0.48
# Best parameters: {'sgdregressor__alpha': 0.001, 'sgdregressor__tol': 0.0001}
#
#
# SGDRegressor Normailzer Score without poly features: -0.04
# Best cross-validation accuracy: -3.37
# Best parameters: {'sgdregressor__alpha': 0.0001, 'sgdregressor__tol': 0.0001}
#
#
# SGDRegressor Robust Score without poly features: 0.40
# Best cross-validation accuracy: -1.81
# Best parameters: {'sgdregressor__alpha': 10, 'sgdregressor__tol': 0.0001}

# %%
#Linear Support Vector Regression
from sklearn.svm import LinearSVR
from sklearn.svm import SVR
svr = SVR(C=16)
svr.fit(X_train, y_train)
print("Training set score: {:.2f}".format(svr.score(X_train, y_train)))
print("Test set score: {:.2f}".format(svr.score(X_test, y_test)))

param_grid = {'svr__C': [0.001, 0.01, 0.1, 1, 10, 100,1000],
              'svr__gamma': [0.0001,0.001, 0.01, 0.1, 1, 10, 100,1000]}
# pipe = make_pipeline(MinMaxScaler(), SVR())
# pipe.get_params().keys()

# MINMAX scaler
pipe = make_pipeline(MinMaxScaler(), SVR())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("SVR MinMax Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Standar scaler
pipe = make_pipeline(StandardScaler(),  SVR())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("SVR STANDAR Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Normalizer scaler
pipe = make_pipeline(Normalizer(),  SVR())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("SVR Normailzer Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")


# Robust scaler
pipe = make_pipeline(RobustScaler(),  SVR())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("SVR Robust Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")
# Out:
# Training set score: 0.93
# Test set score: 0.93
# SVR MinMax Score without poly features: 0.95
# Best cross-validation accuracy: 0.76
# Best parameters: {'svr__C': 100, 'svr__gamma': 0.01}
#
#
# SVR STANDAR Score without poly features: 0.94
# Best cross-validation accuracy: 0.77
# Best parameters: {'svr__C': 100, 'svr__gamma': 0.001}
#
#
# SVR Normailzer Score without poly features: 0.94
# Best cross-validation accuracy: 0.70
# Best parameters: {'svr__C': 10, 'svr__gamma': 100}
#
#
# SVR Robust Score without poly features: 0.93
# Best cross-validation accuracy: 0.79
# Best parameters: {'svr__C': 10, 'svr__gamma': 0.01}

# %%
#DecisionTreeRegressor
# Árboles de decisión regresión
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(max_depth=4)
regressor.fit(X_train, y_train)
print("Training set score: {:.2f}".format(regressor.score(X_train, y_train)))
print("Test set score: {:.2f}".format(regressor.score(X_test, y_test)))
param_grid = {'decisiontreeregressor__max_depth': [1,2,3,4,5,6,7,8],'decisiontreeregressor__min_samples_leaf': [1,2,3,4,5,6,7,8]}
# pipe = make_pipeline(MinMaxScaler(), DecisionTreeRegressor())
# pipe.get_params().keys()

# MINMAX scaler
pipe = make_pipeline(MinMaxScaler(), DecisionTreeRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" DecisionTreeRegressor MinMax Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Standar scaler
pipe = make_pipeline(StandardScaler(),  DecisionTreeRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" DecisionTreeRegressor STANDAR Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Normalizer scaler
pipe = make_pipeline(Normalizer(),  DecisionTreeRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" DecisionTreeRegressor Normailzer Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")


# Robust scaler
pipe = make_pipeline(RobustScaler(),  DecisionTreeRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" DecisionTreeRegressor Robust Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")
# Out:
# Training set score: 1.00
# Test set score: 0.83
#  DecisionTreeRegressor MinMax Score without poly features: 0.97
# Best cross-validation accuracy: 0.94
# Best parameters: {'decisiontreeregressor__max_depth': 4, 'decisiontreeregressor__min_samples_leaf': 1}
#
#
#  DecisionTreeRegressor STANDAR Score without poly features: 0.83
# Best cross-validation accuracy: 0.97
# Best parameters: {'decisiontreeregressor__max_depth': 5, 'decisiontreeregressor__min_samples_leaf': 1}
#
#
#  DecisionTreeRegressor Normailzer Score without poly features: 0.90
# Best cross-validation accuracy: 0.97
# Best parameters: {'decisiontreeregressor__max_depth': 7, 'decisiontreeregressor__min_samples_leaf': 1}
#
#
#  DecisionTreeRegressor Robust Score without poly features: 0.15
# Best cross-validation accuracy: 0.96
# Best parameters: {'decisiontreeregressor__max_depth': 6, 'decisiontreeregressor__min_samples_leaf': 1}

# %%
# Random forest regressor

from sklearn.ensemble import RandomForestRegressor
Forest = RandomForestRegressor(n_estimators=5)
Forest.fit(X_train,y_train)
print("Training set score: {:.2f}".format(Forest.score(X_train, y_train)))
print("Test set score: {:.2f}".format(Forest.score(X_test, y_test)))

# param_grid = {'randomforestregressor__max_depth': [1,2,3,4,5,6,7,8],'randomforestregressor__min_samples_leaf': [1,2,3,4,5,6,7,8],'randomforestregressor__n_estimators':[1,2,3,4,5,6]}
# param_grid = {'randomforestregressor__min_samples_leaf': [1,2,3,4,5,6,7,8],'randomforestregressor__n_estimators':[1,2,3,4,5,6]}
param_grid = {'randomforestregressor__n_estimators':[1,2,3,4,5,6]}

# pipe = make_pipeline(MinMaxScaler(), RandomForestRegressor())
# pipe.get_params().keys()

# MINMAX scaler
pipe = make_pipeline(MinMaxScaler(), RandomForestRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" RandomForestRegressor MinMax Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Standar scaler
pipe = make_pipeline(StandardScaler(),  RandomForestRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" RandomForestRegressor STANDAR Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Normalizer scaler
pipe = make_pipeline(Normalizer(),  RandomForestRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" RandomForestRegressor Normailzer Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")


# Robust scaler
pipe = make_pipeline(RobustScaler(),  RandomForestRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" RandomForestRegressor Robust Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
# print ("\n")
# Out:
# Training set score: 0.96
# Test set score: 0.71
#  RandomForestRegressor MinMax Score without poly features: 0.98
# Best cross-validation accuracy: 0.86
# Best parameters: {'randomforestregressor__n_estimators': 3}
#
#
#  RandomForestRegressor STANDAR Score without poly features: 0.72
# Best cross-validation accuracy: 0.84
# Best parameters: {'randomforestregressor__n_estimators': 4}
#
#
#  RandomForestRegressor Normailzer Score without poly features: 0.93
# Best cross-validation accuracy: 0.86
# Best parameters: {'randomforestregressor__n_estimators': 6}
#
#
#  RandomForestRegressor Robust Score without poly features: 0.88
# Best cross-validation accuracy: 0.96
# Best parameters: {'randomforestregressor__n_estimators': 3}
