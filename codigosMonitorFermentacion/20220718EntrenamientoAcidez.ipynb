# %%
# Código para dataset de café con datos de acidez y con pipelines
# Luz Adriana Plazas Pemberthy 2190651

# %%
# #instalación de librerías no contenidas en colab
# !pip install mglearn
# import mglearn

# %% [markdown]
# **Cargar las librerías básicas y el dataset al programa**
#
# ---

# %%
#importar librerías basicas
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
#importar métodos de preprocesamiento
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import RobustScaler
import statsmodels.formula.api as sm
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor

from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#subir archivo
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fc4192e3-b69e-4255-b5d1-7ac002d9f682" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fc4192e3-b69e-4255-b5d1-7ac002d9f682">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving df_Acidez.csv to df_Acidez.csv

# %%
# Cargar el dataset
Coffee = pd.read_csv("df_Acidez.csv", sep=',')
# Convert string target vector to integer

X = Coffee.loc[:,'Pha':'TDSad']
y = Coffee.loc[:,'Acidez']
#Revisar el tamaño del dataset cargado
print ('X')
print (X.shape)
print ('y')
print (y.shape)
# Out:
# X
# (16, 50)
# y
# (16,)

# %%
# Se realiza la separación del dataset
# B Separar en train y test
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=1)
# print("per-feature minimum before scaling:\n {}".format(X_train.min(axis=0)))
# print("per-feature maximum before scaling:\n {}".format(X_train.max(axis=0)))
# print("target minimum before scaling:\n {}".format(y_train.min(axis=0)))
# print("target maximum before scaling:\n {}".format(y_train.max(axis=0)))

# %% [markdown]
# Pruebas iniciales con los modelos básicos de regresión

# %%
###pruebas de regresión  básica
# Regresion lineal LS
from sklearn.linear_model import LinearRegression
lrLS = LinearRegression()
lrLS.fit(X_train, y_train)
print("Train set score linear regression: {:.2f}".format(lrLS.score(X_train, y_train)))
print("Test set score linear regression: {:.2f}".format(lrLS.score(X_test, y_test)))
# Out:
# Train set score linear regression: 1.00
# Test set score linear regression: 0.82

# %% [markdown]
# **sklearn.metrics**

# %%
 Train_set=X_train
 Train_set['Acidez']=y_train
# Train_set
#50var
#  Modelo=sm.ols(formula='Acidez ~ Pha	+ Muestras	+ Phmax +	Phme	+	Phdif	+	TDSa	+	Phf	+	Alcohola	+	Phd	+	Phv	+	Co2max +	TDSmind	+	Temp1dif	+	Alcoholmax	+	Alcoholdif	+	Co2dif	+	Alcoholdifd	+	Co2d	+	Temp2dif	+	Phmo	+	Alcoholme	+	Alcoholmaxd	+	Co2v	+	Co2fd	+	Temp1maxd+ Temp1max	+	Alcoholf	+	Temp2f	+	Temp2a	+	Phmod	+	Temp2ad	+	Phdd	+	Alcoholv	+	Phvd	+	Alcohold	+	Alcoholi	+	Alcoholmin	+	Temp2min	+	Co2f	+	TDSmaxd	+	TDSv	+	TDSdifd	+	TDSd	+	TDSvd	+	TDSdd	+	Temp1ad	+	Alcoholad	+	Phad	+	Co2ad	+	TDSad', data= Train_set)
#22var
# Modelo=sm.ols(formula='Acidez ~ Pha	+ Muestras	+ Phmax +	Phme	+	Phdif	+	TDSa	+	Phf	+	Alcohola	+	Phd	+	Phv	+	Co2max +	TDSmaxd	+	TDSv	+	TDSdifd	+	TDSd	+	TDSvd	+	TDSdd	+	Temp1ad	+	Alcoholad	+	Phad	+	Co2ad	+	TDSad', data= Train_set)
#13var
# Modelo=sm.ols(formula='Acidez ~ Pha	+ Muestras	+ Phmax +	Phme	+	Phdif	+	TDSa	+	Phf	+	Alcohola	+	Phd	+	Temp1ad	+	Alcoholad	+	Phad	+	Co2ad	+	TDSad', data= Train_set)
#7var (1 de cada 1)
Modelo=sm.ols(formula='Acidez ~ Pha	+ Muestras	+ TDSa	+	Alcohola	+	Temp1ad	+	Co2ad + Temp2min', data= Train_set)
# Modelo=sm.ols(formula='Acidez ~ Pha	+ Muestras	+ Phmax +	Phme	+	Phdif	+	TDSa	+	Phf	+	Alcohola + Temp1ad	+	Alcoholad	+	Phad	+	Co2ad	+	TDSad', data= Train_set)
#Modelo=sm.ols(formula='Acidez ~ Pha	+ Muestras + TDSa + Alcohola +	Co2max	+ TDSad', data= Train_set)
Fitted=Modelo.fit()
print(Fitted.summary())
Prediccion=Fitted.predict(X_test) #guardar la predicción y luego sacar el error
print('\n\n MSE:\t',mean_squared_error(y_test,Prediccion))
print('\n MAE:\t',mean_absolute_error(y_test,Prediccion))
print('\n R2 Score test:\t',r2_score(y_test,Prediccion),'\n')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Acidez   R-squared:                       0.978
# Model:                            OLS   Adj. R-squared:                  0.941
# Method:                 Least Squares   F-statistic:                     25.86
# Date:                Sun, 14 Aug 2022   Prob (F-statistic):            0.00355
# Time:                        00:04:55   Log-Likelihood:                 26.278
# No. Observations:                  12   AIC:                            -36.56
# Df Residuals:                       4   BIC:                            -32.68
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.6457      1.308      3.552      0.024       1.015       8.277
# Pha            0.0007      0.001      0.489      0.650      -0.003       0.005
# Muestras    2.175e-05   4.62e-05      0.471      0.662      -0.000       0.000
# TDSa           0.0043      0.002      2.291      0.084      -0.001       0.010
# Alcohola       0.0008      0.001      0.976      0.384      -0.002       0.003
# Temp1ad      -33.4052    231.844     -0.144      0.892    -677.107     610.297
# Co2ad          2.7722      5.493      0.505      0.640     -12.478      18.023
# Temp2min       0.0030      0.033      0.091      0.932      -0.089       0.095
# ==============================================================================
# Omnibus:                        0.634   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.728   Jarque-Bera (JB):                0.608
# Skew:                          -0.250   Prob(JB):                        0.738
# Kurtosis:                       2.017   Cond. No.                     7.21e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.21e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  MSE:	 0.006736072443420267
#
#  MAE:	 0.06406060884636489
#
#  R2 Score test:	 0.8600296635133451
# /usr/local/lib/python3.7/dist-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   "anyway, n=%i" % int(n))

# %%
Coffee = pd.read_csv("df_Acidez.csv", sep=',')
X = Coffee.loc[:,'Pha':'TDSad']
y = Coffee.loc[:,'Acidez']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
# X_train=X.loc[[0,1,2,4,5,6,8,9,10,12,13,14]]
# X_test=X.loc[[3,7,11,15]]
# y_train=y.loc[[0,1,2,4,5,6,8,9,10,12,13,14]]
# y_test=y.loc[[3,7,11,15]]

col_sec=['Pha'	, 'Muestras'	, 'TDSa'	,	'Alcohola'	,	'Temp1ad'	,	'Co2ad', 'Temp2min']
X_train=X_train[col_sec]
X_test=X_test[col_sec]
# X_test
# y_test
#X_train

# %%
# Preprocesamiento de datos
#minmax scaler
minmaxscaler = MinMaxScaler()
minmaxscaler.fit(X_train)
#creo una nueva variable donde guardo el dataset transformado
X_train_scaledm = minmaxscaler.transform(X_train)
X_test_scaledm = minmaxscaler.transform(X_test)
#Standard scaler
stander_s = StandardScaler()
stander_s.fit(X_train)
#creo una nueva variable donde guardo el dataset transformado
X_train_scaledS = stander_s.transform(X_train)
X_test_scaledS = stander_s.transform(X_test)
#Normalizer scaler
stander_n = Normalizer()
stander_n.fit(X_train)
#creo una nueva variable donde guardo el dataset transformado
X_train_scaledn = stander_n.transform(X_train)
X_test_scaledn = stander_n.transform(X_test)
#Robust scaler
stander_r = RobustScaler()
stander_r.fit(X_train)
#creo una nueva variable donde guardo el dataset transformado
X_train_scaledr = stander_r.transform(X_train)
X_test_scaledr = stander_r.transform(X_test)

# %%
lrLS = LinearRegression()
lrLS.fit(X_train, y_train)
print("Train set score linear regression: {:.2f}".format(lrLS.score(X_train, y_train)))
print("Test set score linear regression: {:.2f}".format(lrLS.score(X_test, y_test)))
# Out:
# Train set score linear regression: 0.98
# Test set score linear regression: 0.86

# %%
# regresión lineal con Ridge
from sklearn.linear_model import Ridge
ridge = Ridge().fit(X_train, y_train)
print("Training set score Ridge regression: {:.2f}".format(ridge.score(X_train, y_train)))
print("Test set score Ridge regression: {:.2f}".format(ridge.score(X_test, y_test)))
# Out:
# Training set score Ridge regression: 0.98
# Test set score Ridge regression: 0.90

# %%
print(ridge.get_params)
print(ridge.intercept_)
print(ridge.coef_)
# Out:
# <bound method BaseEstimator.get_params of Ridge()>
# 5.1082761703157304
# [ 1.78150648e-04  3.10160761e-05  3.82605027e-03  8.16076633e-04
#  -4.52253919e-06  3.09582211e-04  4.31847385e-03]

# %%
#Optimizacion de hiperparámetros con Pipeline and GridSearch
# param_grid = {'alpha': [0.0001,0.001, 0.01, 0.1, 1, 10, 100, 1000]}
param_grid = {'ridge__alpha': [0.0001,0.001, 0.01, 0.1, 1, 10, 100, 1000]}
# MINMAX scaler
pipe = make_pipeline(MinMaxScaler(), Ridge())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("RIDGE MinMax Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Standar scaler
pipe = make_pipeline(StandardScaler(), Ridge())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("RIDGE STANDAR Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Normalizer scaler
pipe = make_pipeline(Normalizer(), Ridge())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("RIDGE Normailzer Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")


# Robust scaler
pipe = make_pipeline(RobustScaler(), Ridge())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("RIDGE Robust Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")
# Out:
# RIDGE MinMax Score without poly features: 0.93
# Best cross-validation accuracy: 0.70
# Best parameters: {'ridge__alpha': 1}
#
#
# RIDGE STANDAR Score without poly features: 0.93
# Best cross-validation accuracy: 0.71
# Best parameters: {'ridge__alpha': 10}
#
#
# RIDGE Normailzer Score without poly features: 0.99
# Best cross-validation accuracy: 0.80
# Best parameters: {'ridge__alpha': 0.001}
#
#
# RIDGE Robust Score without poly features: 0.93
# Best cross-validation accuracy: 0.71
# Best parameters: {'ridge__alpha': 1}

# %%
ridge = Ridge(alpha=0.001).fit(X_train_scaledn, y_train)
print("Training set score Ridge regression: {:.2f}".format(ridge.score(X_train_scaledn, y_train)))
print("Test set score Ridge regression: {:.2f}".format(ridge.score(X_test_scaledn, y_test)))
# Out:
# Training set score Ridge regression: 0.96
# Test set score Ridge regression: 0.99

# %%
print(ridge.get_params)
print(ridge.intercept_)
print(ridge.coef_)
# Out:
# <bound method BaseEstimator.get_params of Ridge(alpha=0.001)>
# 8.084713862065591
# [-1.18994111e+00 -3.39970251e-02 -7.43582890e-01 -1.31622696e+00
#  -3.49427060e-06  2.31888032e-04 -2.09820559e-02]

# %%
#Regresión lineal con lasso
from sklearn.linear_model import Lasso
lasso = Lasso(max_iter=10000).fit(X_train, y_train)
print("Training set score Lasso Regression: {:.2f}".format(lasso.score(X_train, y_train)))
print("Test set score Lasso Regression: {:.2f}".format(lasso.score(X_test, y_test)))
print("Number of features used Lasso Regression:", np.sum(lasso.coef_ != 0))
# Out:
# Training set score Lasso Regression: 0.92
# Test set score Lasso Regression: 0.94
# Number of features used Lasso Regression: 1

# %%
#Optimizacion de hiperparámetros con Pipeline and GridSearch

param_grid = {'lasso__alpha': [0.0001,0.001, 0.01, 0.1, 1, 10, 100, 1000], 'lasso__tol': [0.00001,0.0001,0.001]}
# MINMAX scaler
pipe = make_pipeline(MinMaxScaler(), Lasso())
pipe.get_params().keys()
# pipe = make_pipeline(MinMaxScaler(), Lasso())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("Lasso MinMax Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Standar scaler
pipe = make_pipeline(StandardScaler(), Lasso())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("Lasso STANDAR Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Normalizer scaler
pipe = make_pipeline(Normalizer(), Lasso())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("Lasso Normailzer Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")


# Robust scaler
pipe = make_pipeline(RobustScaler(), Lasso())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("Lasso Robust Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.839e-06, tolerance: 3.610e-06
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.642e-05, tolerance: 3.652e-06
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# Lasso MinMax Score without poly features: 0.90
# Best cross-validation accuracy: 0.57
# Best parameters: {'lasso__alpha': 0.001, 'lasso__tol': 0.001}
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.315e-04, tolerance: 3.652e-06
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.184e-05, tolerance: 3.822e-06
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.315e-04, tolerance: 3.652e-05
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# Lasso STANDAR Score without poly features: 0.88
# Best cross-validation accuracy: 0.72
# Best parameters: {'lasso__alpha': 0.01, 'lasso__tol': 0.001}
#
#
# Lasso Normailzer Score without poly features: 0.99
# Best cross-validation accuracy: 0.77
# Best parameters: {'lasso__alpha': 0.0001, 'lasso__tol': 1e-05}
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.682e-06, tolerance: 3.610e-06
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.040e-04, tolerance: 3.652e-06
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.872e-05, tolerance: 3.822e-06
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.040e-04, tolerance: 3.652e-05
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# Lasso Robust Score without poly features: 0.86
# Best cross-validation accuracy: 0.88
# Best parameters: {'lasso__alpha': 0.01, 'lasso__tol': 0.001}

# %%
#Bayesian Ridge Regression
from sklearn import linear_model
Bay= linear_model.BayesianRidge()
Bay.fit(X_train, y_train)
print("Training set score Bayesian Ridge Regression: {:.2f}".format(Bay.score(X_train, y_train)))
print("Test set score Bayesian Ridge Regression: {:.2f}".format(Bay.score(X_test, y_test)))
print ("\n")
#print ("Los modelos básicos han arrojado malos resultados")
# Out:
# Training set score Bayesian Ridge Regression: 0.97
# Test set score Bayesian Ridge Regression: 0.94

# %%
#Optimizacion de hiperparámetros con Pipeline and GridSearch

param_grid = {'bayesianridge__alpha_1': [1e-2, 0.1, 1, 10, 100, 1000], 'bayesianridge__tol': [0.00001,0.0001,0.001]}
# MINMAX scaler
pipe = make_pipeline(MinMaxScaler(), linear_model.BayesianRidge())
pipe.get_params().keys()
# pipe = make_pipeline(MinMaxScaler(), Lasso())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("BayesianRidge MinMax Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Standar scaler
pipe = make_pipeline(StandardScaler(), linear_model.BayesianRidge())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("BayesianRidge STANDAR Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Normalizer scaler
pipe = make_pipeline(Normalizer(), linear_model.BayesianRidge())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("BayesianRidge Normailzer Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")


# Robust scaler
pipe = make_pipeline(RobustScaler(), linear_model.BayesianRidge())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("BayesianRidge Robust Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")
# Out:
# BayesianRidge MinMax Score without poly features: 0.93
# Best cross-validation accuracy: 0.57
# Best parameters: {'bayesianridge__alpha_1': 0.01, 'bayesianridge__tol': 1e-05}
#
#
# BayesianRidge STANDAR Score without poly features: 0.92
# Best cross-validation accuracy: 0.59
# Best parameters: {'bayesianridge__alpha_1': 0.01, 'bayesianridge__tol': 1e-05}
#
#
# BayesianRidge Normailzer Score without poly features: 0.99
# Best cross-validation accuracy: 0.79
# Best parameters: {'bayesianridge__alpha_1': 0.01, 'bayesianridge__tol': 0.001}
#
#
# BayesianRidge Robust Score without poly features: 0.91
# Best cross-validation accuracy: 0.66
# Best parameters: {'bayesianridge__alpha_1': 0.01, 'bayesianridge__tol': 1e-05}

# %%
print(Bay.get_params)
print(Bay.intercept_)
print(Bay.coef_)
# Out:
# <bound method BaseEstimator.get_params of BayesianRidge()>
# 5.722735934671347
# [ 3.88729407e-04  4.00829407e-05  2.39068011e-03  7.42208671e-04
#  -9.93731593e-09  7.81292176e-08 -7.59874454e-06]

# %%
#Stochastic Gradient Descent SGDRegressor 
from sklearn.linear_model import SGDRegressor
SGDreg = SGDRegressor(max_iter=1000, tol=1e-3)
SGDreg.fit (X_train, y_train)
print("Training set score SGD Regressor: {:.2f}".format(SGDreg.score(X_train, y_train)))
print("Test set score SGD Regressor: {:.2f}".format(SGDreg.score(X_test, y_test)))
# Out:
# Training set score SGD Regressor: -5874823059718293808673109426831360.00
# Test set score SGD Regressor: -2836945909344550208089710087110656.00

# %%
#Optimizacion de hiperparámetros con Pipeline and GridSearch

param_grid = {'sgdregressor__alpha': [0.0001, 0.001, 0.01, 0.1, 10, 100],
              'sgdregressor__tol': [0.0001,0.001, 0.01, 0.1, 1, 10, 100,1000]}

# pipe = make_pipeline(MinMaxScaler(), SGDRegressor(max_iter=10000))
# pipe.get_params().keys()

# MINMAX scaler
pipe = make_pipeline(MinMaxScaler(), SGDRegressor(max_iter=10000))
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("SGDRegressor MinMax Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Standar scaler
pipe = make_pipeline(StandardScaler(), SGDRegressor(max_iter=10000))
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("SGDRegressor STANDAR Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Normalizer scaler
pipe = make_pipeline(Normalizer(), SGDRegressor(max_iter=10000))
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("SGDRegressor Normailzer Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")


# Robust scaler
pipe = make_pipeline(RobustScaler(), SGDRegressor(max_iter=10000))
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("SGDRegressor Robust Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
# print ("\n")
# Out:
# SGDRegressor MinMax Score without poly features: 0.09
# Best cross-validation accuracy: -2.57
# Best parameters: {'sgdregressor__alpha': 10, 'sgdregressor__tol': 0.0001}
#
#
# SGDRegressor STANDAR Score without poly features: 0.90
# Best cross-validation accuracy: -0.08
# Best parameters: {'sgdregressor__alpha': 0.1, 'sgdregressor__tol': 0.0001}
#
#
# SGDRegressor Normailzer Score without poly features: 0.21
# Best cross-validation accuracy: -1.69
# Best parameters: {'sgdregressor__alpha': 0.0001, 'sgdregressor__tol': 0.0001}
#
#
# SGDRegressor Robust Score without poly features: 0.44
# Best cross-validation accuracy: -1.10
# Best parameters: {'sgdregressor__alpha': 10, 'sgdregressor__tol': 0.0001}

# %%
#Linear Support Vector Regression
from sklearn.svm import LinearSVR
from sklearn.svm import SVR
svr = SVR(C=16)
svr.fit(X_train, y_train)
print("Training set score: {:.2f}".format(svr.score(X_train, y_train)))
print("Test set score: {:.2f}".format(svr.score(X_test, y_test)))
# Out:
# Training set score: 0.82
# Test set score: 0.86

# %%
param_grid = {'svr__C': [0.001, 0.01, 0.1, 1, 10, 100,1000],
              'svr__gamma': [0.0001,0.001, 0.01, 0.1, 1, 10, 100,1000]}
# pipe = make_pipeline(MinMaxScaler(), SVR())
# pipe.get_params().keys()

# MINMAX scaler
pipe = make_pipeline(MinMaxScaler(), SVR())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("SVR MinMax Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Standar scaler
pipe = make_pipeline(StandardScaler(),  SVR())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("SVR STANDAR Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Normalizer scaler
pipe = make_pipeline(Normalizer(),  SVR())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("SVR Normailzer Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")


# Robust scaler
pipe = make_pipeline(RobustScaler(),  SVR())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("SVR Robust Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")
# Out:
# SVR MinMax Score without poly features: 0.85
# Best cross-validation accuracy: 0.32
# Best parameters: {'svr__C': 1000, 'svr__gamma': 0.0001}
#
#
# SVR STANDAR Score without poly features: 0.85
# Best cross-validation accuracy: 0.34
# Best parameters: {'svr__C': 100, 'svr__gamma': 0.0001}
#
#
# SVR Normailzer Score without poly features: 0.87
# Best cross-validation accuracy: 0.36
# Best parameters: {'svr__C': 1000, 'svr__gamma': 0.01}
#
#
# SVR Robust Score without poly features: 0.87
# Best cross-validation accuracy: 0.25
# Best parameters: {'svr__C': 100, 'svr__gamma': 0.0001}

# %%
# Árboles de decisión regresión
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(max_depth=4)
regressor.fit(X_train, y_train)
print("Training set score: {:.2f}".format(regressor.score(X_train, y_train)))
print("Test set score: {:.2f}".format(regressor.score(X_test, y_test)))
# Out:
# Training set score: 1.00
# Test set score: 0.56

# %%
param_grid = {'decisiontreeregressor__max_depth': [1,2,3,4,5,6,7,8]}
# solo con max_depth (OJO)
# solo con min samples leaf (APARTE)

# pipe = make_pipeline(MinMaxScaler(), DecisionTreeRegressor())
# pipe.get_params().keys()

# MINMAX scaler
pipe = make_pipeline(MinMaxScaler(), DecisionTreeRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" DecisionTreeRegressor MinMax Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Standar scaler
pipe = make_pipeline(StandardScaler(),  DecisionTreeRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" DecisionTreeRegressor STANDAR Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Normalizer scaler
pipe = make_pipeline(Normalizer(),  DecisionTreeRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" DecisionTreeRegressor Normailzer Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")


# Robust scaler
pipe = make_pipeline(RobustScaler(),  DecisionTreeRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" DecisionTreeRegressor Robust Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")
# Out:
#  DecisionTreeRegressor MinMax Score without poly features: 0.99
# Best cross-validation accuracy: 0.66
# Best parameters: {'decisiontreeregressor__max_depth': 7}
#
#
#  DecisionTreeRegressor STANDAR Score without poly features: 0.47
# Best cross-validation accuracy: 0.69
# Best parameters: {'decisiontreeregressor__max_depth': 7}
#
#
#  DecisionTreeRegressor Normailzer Score without poly features: 0.99
# Best cross-validation accuracy: 0.49
# Best parameters: {'decisiontreeregressor__max_depth': 3}
#
#
#  DecisionTreeRegressor Robust Score without poly features: 0.97
# Best cross-validation accuracy: 0.69
# Best parameters: {'decisiontreeregressor__max_depth': 7}

# %%
param_grid = {'decisiontreeregressor__min_samples_leaf': [1,2,3,4,5,6,7,8]}
# solo con max_depth (OJO)
# solo con min samples leaf (APARTE)

# pipe = make_pipeline(MinMaxScaler(), DecisionTreeRegressor())
# pipe.get_params().keys()

# MINMAX scaler
pipe = make_pipeline(MinMaxScaler(), DecisionTreeRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" DecisionTreeRegressor MinMax Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Standar scaler
pipe = make_pipeline(StandardScaler(),  DecisionTreeRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" DecisionTreeRegressor STANDAR Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Normalizer scaler
pipe = make_pipeline(Normalizer(),  DecisionTreeRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" DecisionTreeRegressor Normailzer Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")


# Robust scaler
pipe = make_pipeline(RobustScaler(),  DecisionTreeRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" DecisionTreeRegressor Robust Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")
# Out:
#  DecisionTreeRegressor MinMax Score without poly features: 0.52
# Best cross-validation accuracy: 0.47
# Best parameters: {'decisiontreeregressor__min_samples_leaf': 2}
#
#
#  DecisionTreeRegressor STANDAR Score without poly features: 0.99
# Best cross-validation accuracy: 0.67
# Best parameters: {'decisiontreeregressor__min_samples_leaf': 1}
#
#
#  DecisionTreeRegressor Normailzer Score without poly features: 0.99
# Best cross-validation accuracy: 0.42
# Best parameters: {'decisiontreeregressor__min_samples_leaf': 2}
#
#
#  DecisionTreeRegressor Robust Score without poly features: 0.99
# Best cross-validation accuracy: 0.54
# Best parameters: {'decisiontreeregressor__min_samples_leaf': 1}

# %%
# Random forest regressor

from sklearn.ensemble import RandomForestRegressor
Forest = RandomForestRegressor(n_estimators=5)
Forest.fit(X_train,y_train)
print("Training set score: {:.2f}".format(Forest.score(X_train, y_train)))
print("Test set score: {:.2f}".format(Forest.score(X_test, y_test)))
# Out:
# Training set score: 0.98
# Test set score: 0.66

# %%
# param_grid = {'randomforestregressor__max_depth': [1,2,3,4,5,6,7,8],'randomforestregressor__min_samples_leaf': [1,2,3,4,5,6,7,8],'randomforestregressor__n_estimators':[1,2,3,4,5,6]}
# param_grid = {'randomforestregressor__min_samples_leaf': [1,2,3,4,5,6,7,8],'randomforestregressor__n_estimators':[1,2,3,4,5,6]}
param_grid = {'randomforestregressor__n_estimators':[1,2,3,4,5,6]}

# pipe = make_pipeline(MinMaxScaler(), RandomForestRegressor())
# pipe.get_params().keys()

# MINMAX scaler
pipe = make_pipeline(MinMaxScaler(), RandomForestRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" RandomForestRegressor MinMax Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Standar scaler
pipe = make_pipeline(StandardScaler(),  RandomForestRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" RandomForestRegressor STANDAR Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Normalizer scaler
pipe = make_pipeline(Normalizer(),  RandomForestRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" RandomForestRegressor Normailzer Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")


# Robust scaler
pipe = make_pipeline(RobustScaler(),  RandomForestRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" RandomForestRegressor Robust Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
# print ("\n")
# Out:
#  RandomForestRegressor MinMax Score without poly features: 0.93
# Best cross-validation accuracy: 0.65
# Best parameters: {'randomforestregressor__n_estimators': 5}
#
#
#  RandomForestRegressor STANDAR Score without poly features: 0.89
# Best cross-validation accuracy: 0.65
# Best parameters: {'randomforestregressor__n_estimators': 5}
#
#
#  RandomForestRegressor Normailzer Score without poly features: 0.99
# Best cross-validation accuracy: 0.56
# Best parameters: {'randomforestregressor__n_estimators': 2}
#
#
#  RandomForestRegressor Robust Score without poly features: 0.83
# Best cross-validation accuracy: 0.59
# Best parameters: {'randomforestregressor__n_estimators': 3}
