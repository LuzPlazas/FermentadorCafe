# %%
# Código para dataset de café con datos de cuerpo y con pipelines
# Luz Adriana Plazas Pemberthy 2190651

# %%
#instalación de librerías no contenidas en colab
# !pip install mglearn
# import mglearn

# %% [markdown]
# **Cargar las librerías básicas y el dataset al programa**
#
# ---

# %%
#importar librerías basicas
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
#importar métodos de preprocesamiento
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import RobustScaler
import statsmodels.formula.api as sm
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#subir archivo
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c2d4ad1e-b5c4-4efa-8cad-09c6a7561004" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c2d4ad1e-b5c4-4efa-8cad-09c6a7561004">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving df_Cuerpo.csv to df_Cuerpo.csv

# %%
# Cargar el dataset
Coffee = pd.read_csv("df_Cuerpo.csv", sep=',')
# Convert string target vector to integer

X = Coffee.loc[:,'TDSa':'Alcoholad']
y = Coffee.loc[:,'Cuerpo']
#Revisar el tamaño del dataset cargado
print ('X')
print (X.shape)
print ('y')
print (y.shape)
# Out:
# X
# (16, 44)
# y
# (16,)

# %%
# Se realiza la separación del dataset
# B Separar en train y test
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=1)
# print("per-feature minimum before scaling:\n {}".format(X_train.min(axis=0)))
# print("per-feature maximum before scaling:\n {}".format(X_train.max(axis=0)))
# print("target minimum before scaling:\n {}".format(y_train.min(axis=0)))
# print("target maximum before scaling:\n {}".format(y_train.max(axis=0)))

# %% [markdown]
# Pruebas iniciales con los modelos básicos de regresión

# %%
###pruebas de regresión  básica
# Regresion lineal LS
from sklearn.linear_model import LinearRegression
lrLS = LinearRegression()
lrLS.fit(X_train, y_train)
print("Train set score linear regression: {:.2f}".format(lrLS.score(X_train, y_train)))
print("Test set score linear regression: {:.2f}".format(lrLS.score(X_test, y_test)))
# Out:
# Train set score linear regression: 1.00
# Test set score linear regression: 0.21

# %%
 Train_set=X_train
 Train_set['Cuerpo']=y_train
#  Modelo=sm.ols(formula='Cuerpo ~ TDSa + Muestras + Pha + Phme + Phmax + Phf + Phdif + Alcohola + TDSmind + Phv + Phd + Co2fd + Co2max + Co2d + Phmo + Co2dif + Co2v + Alcoholdifd + Temp1dif + Temp1maxd + Alcoholmax + Alcoholmaxd + Temp1max + Temp1difd + Temp2a + Temp2f + TDSf + Temp2ad + Temp2min + Alcoholf + TDSvd + TDSdifd + Co2f + TDSdd + Alcoholv + Alcohold + TDSmaxd + Phad + TDSv + TDSd + Co2ad + TDSad + Temp1ad + Alcoholad', data= Train_set)
#  Modelo=sm.ols(formula='Cuerpo ~ TDSa + Muestras + Pha + Phme + Phmax + Phf + Phdif + TDSvd + TDSdifd + Co2f + TDSdd + Alcoholv + Alcohold + TDSmaxd + Phad + TDSv + TDSd + Co2ad + TDSad + Temp1ad + Alcoholad', data= Train_set)
 Modelo=sm.ols(formula='Cuerpo ~ TDSa + Muestras + Pha + Co2ad+ Temp2min+ Temp1ad + Alcoholad', data= Train_set)
 Fitted=Modelo.fit()
 print(Fitted.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Cuerpo   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.982
# Method:                 Least Squares   F-statistic:                     85.42
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):           0.000344
# Time:                        02:32:09   Log-Likelihood:                 34.667
# No. Observations:                  12   AIC:                            -53.33
# Df Residuals:                       4   BIC:                            -49.45
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.4699      1.006      5.438      0.006       2.677       8.263
# TDSa           0.0048      0.002      2.456      0.070      -0.001       0.010
# Muestras    5.594e-05   2.24e-05      2.495      0.067   -6.32e-06       0.000
# Pha           -0.0009      0.001     -1.086      0.338      -0.003       0.001
# Co2ad         -0.7702      3.577     -0.215      0.840     -10.702       9.161
# Temp2min       0.0160      0.019      0.845      0.446      -0.037       0.069
# Temp1ad     -126.4693    157.590     -0.803      0.467    -564.008     311.070
# Alcoholad      0.1638      1.187      0.138      0.897      -3.133       3.461
# ==============================================================================
# Omnibus:                        3.802   Durbin-Watson:                   2.123
# Prob(Omnibus):                  0.149   Jarque-Bera (JB):                2.277
# Skew:                           1.058   Prob(JB):                        0.320
# Kurtosis:                       2.730   Cond. No.                     9.77e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.77e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.7/dist-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   "anyway, n=%i" % int(n))

# %%
Prediccion=Fitted.predict(X_test) #guardar la predicción y luego sacar el error
print('\n\n MSE:\t',mean_squared_error(y_test,Prediccion))
print('\n MAE:\t',mean_absolute_error(y_test,Prediccion))
print('\n R2 Score test:\t',r2_score(y_test,Prediccion),'\n')
# Out:
#  MSE:	 0.004668985484601705
#
#  MAE:	 0.05261467116935514
#
#  R2 Score test:	 0.7207335784911125

# %%
Coffee = pd.read_csv("df_Cuerpo.csv", sep=',')
X = Coffee.loc[:,'TDSa':'Alcoholad']
y = Coffee.loc[:,'Cuerpo']
#split
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=1)
#split manual
# X_train=X.loc[[0,1,2,4,5,6,8,9,10,12,13,14]]
# X_test=X.loc[[3,7,11,15]]
# y_train=y.loc[[0,1,2,4,5,6,8,9,10,12,13,14]]
# y_test=y.loc[[3,7,11,15]]
col_sec=['TDSa' , 'Muestras' , 'Pha' , 'Co2ad', 'Temp2min', 'Temp1ad' , 'Alcoholad']
X_train=X_train[col_sec]
X_test=X_test[col_sec]

# %%
lrLS = LinearRegression()
lrLS.fit(X_train, y_train)
print("Train set score linear regression: {:.2f}".format(lrLS.score(X_train, y_train)))
print("Test set score linear regression: {:.2f}".format(lrLS.score(X_test, y_test)))
# Out:
# Train set score linear regression: 0.99
# Test set score linear regression: 0.72

# %% [markdown]
# Prueba Mejor modelo

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline

# %%
# regresión lineal con Ridge
from sklearn.linear_model import Ridge
ridge = Ridge().fit(X_train, y_train)
print("Training set score Ridge regression: {:.2f}".format(ridge.score(X_train, y_train)))
print("Test set score Ridge regression: {:.2f}".format(ridge.score(X_test, y_test)))
#Optimizacion de hiperparámetros con Pipeline and GridSearch
# param_grid = {'alpha': [0.0001,0.001, 0.01, 0.1, 1, 10, 100, 1000]}
param_grid = {'ridge__alpha': [0.0001,0.001, 0.01, 0.1, 1, 10, 100, 1000]}
print ("\n")
# MINMAX scaler
pipe = make_pipeline(MinMaxScaler(), Ridge())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("RIDGE MinMax Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Standar scaler
pipe = make_pipeline(StandardScaler(), Ridge())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("RIDGE STANDAR Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Normalizer scaler
pipe = make_pipeline(Normalizer(), Ridge())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("RIDGE Normailzer Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")


# Robust scaler
pipe = make_pipeline(RobustScaler(), Ridge())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("RIDGE Robust Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
# Out:
# Training set score Ridge regression: 0.99
# Test set score Ridge regression: 0.51
#
#
# RIDGE MinMax Score without poly features: 0.69
# Best cross-validation accuracy: 0.79
# Best parameters: {'ridge__alpha': 0.1}
#
#
# RIDGE STANDAR Score without poly features: 0.67
# Best cross-validation accuracy: 0.79
# Best parameters: {'ridge__alpha': 0.1}
#
#
# RIDGE Normailzer Score without poly features: -0.29
# Best cross-validation accuracy: 0.76
# Best parameters: {'ridge__alpha': 0.001}
#
#
# RIDGE Robust Score without poly features: 0.61
# Best cross-validation accuracy: 0.83
# Best parameters: {'ridge__alpha': 0.1}

# %%
#Regresión lineal con lasso
from sklearn.linear_model import Lasso
lasso = Lasso(max_iter=10000).fit(X_train, y_train)
print("Training set score Lasso Regression: {:.2f}".format(lasso.score(X_train, y_train)))
print("Test set score Lasso Regression: {:.2f}".format(lasso.score(X_test, y_test)))
print("Number of features used Lasso Regression:", np.sum(lasso.coef_ != 0))

#Optimizacion de hiperparámetros con Pipeline and GridSearch

param_grid = {'lasso__alpha': [0.0001,0.001, 0.01, 0.1, 1, 10, 100, 1000], 'lasso__tol': [0.00001,0.0001,0.001]}
# MINMAX scaler
pipe = make_pipeline(MinMaxScaler(), Lasso())
pipe.get_params().keys()
# pipe = make_pipeline(MinMaxScaler(), Lasso())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("Lasso MinMax Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Standar scaler
pipe = make_pipeline(StandardScaler(), Lasso())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("Lasso STANDAR Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Normalizer scaler
pipe = make_pipeline(Normalizer(), Lasso())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("Lasso Normailzer Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")


# Robust scaler
pipe = make_pipeline(RobustScaler(), Lasso())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("Lasso Robust Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")
# Out:
# Training set score Lasso Regression: 0.93
# Test set score Lasso Regression: 0.20
# Number of features used Lasso Regression: 1
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.002e-05, tolerance: 8.000e-07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.199e-04, tolerance: 2.852e-06
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.002e-05, tolerance: 8.000e-06
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.199e-04, tolerance: 2.852e-05
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# Lasso MinMax Score without poly features: 0.42
# Best cross-validation accuracy: 0.87
# Best parameters: {'lasso__alpha': 0.001, 'lasso__tol': 0.001}
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.005e-04, tolerance: 8.000e-07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.330e-04, tolerance: 2.852e-06
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.005e-04, tolerance: 8.000e-06
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.330e-04, tolerance: 2.852e-05
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.005e-04, tolerance: 8.000e-05
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.328e-06, tolerance: 2.852e-06
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# Lasso STANDAR Score without poly features: 0.52
# Best cross-validation accuracy: 0.87
# Best parameters: {'lasso__alpha': 0.01, 'lasso__tol': 0.001}
#
#
# Lasso Normailzer Score without poly features: 0.04
# Best cross-validation accuracy: 0.73
# Best parameters: {'lasso__alpha': 0.0001, 'lasso__tol': 1e-05}
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.795e-05, tolerance: 8.000e-07
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.949e-04, tolerance: 2.852e-06
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.795e-05, tolerance: 8.000e-06
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.949e-04, tolerance: 2.852e-05
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.795e-05, tolerance: 8.000e-05
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# Lasso Robust Score without poly features: 0.36
# Best cross-validation accuracy: 0.84
# Best parameters: {'lasso__alpha': 0.001, 'lasso__tol': 0.001}

# %%
#Bayesian Ridge Regression
from sklearn import linear_model
Bay= linear_model.BayesianRidge()
Bay.fit(X_train, y_train)
print("Training set score Bayesian Ridge Regression: {:.2f}".format(Bay.score(X_train, y_train)))
print("Test set score Bayesian Ridge Regression: {:.2f}".format(Bay.score(X_test, y_test)))
print ("\n")
#print ("Los modelos básicos han arrojado malos resultados")
#Optimizacion de hiperparámetros con Pipeline and GridSearch

param_grid = {'bayesianridge__alpha_1': [1e-2, 0.1, 1, 10, 100, 1000], 'bayesianridge__tol': [0.00001,0.0001,0.001]}
# MINMAX scaler
pipe = make_pipeline(MinMaxScaler(), linear_model.BayesianRidge())
pipe.get_params().keys()
# pipe = make_pipeline(MinMaxScaler(), Lasso())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("BayesianRidge MinMax Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Standar scaler
pipe = make_pipeline(StandardScaler(), linear_model.BayesianRidge())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("BayesianRidge STANDAR Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Normalizer scaler
pipe = make_pipeline(Normalizer(), linear_model.BayesianRidge())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("BayesianRidge Normailzer Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")


# Robust scaler
pipe = make_pipeline(RobustScaler(), linear_model.BayesianRidge())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("BayesianRidge Robust Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")
# Out:
# Training set score Bayesian Ridge Regression: 0.99
# Test set score Bayesian Ridge Regression: 0.50
#
#
# BayesianRidge MinMax Score without poly features: 0.68
# Best cross-validation accuracy: 0.73
# Best parameters: {'bayesianridge__alpha_1': 0.01, 'bayesianridge__tol': 0.001}
#
#
# BayesianRidge STANDAR Score without poly features: 0.67
# Best cross-validation accuracy: 0.74
# Best parameters: {'bayesianridge__alpha_1': 0.01, 'bayesianridge__tol': 1e-05}
#
#
# BayesianRidge Normailzer Score without poly features: 0.00
# Best cross-validation accuracy: 0.69
# Best parameters: {'bayesianridge__alpha_1': 0.01, 'bayesianridge__tol': 1e-05}
#
#
# BayesianRidge Robust Score without poly features: 0.61
# Best cross-validation accuracy: 0.75
# Best parameters: {'bayesianridge__alpha_1': 0.01, 'bayesianridge__tol': 0.001}

# %%
#Stochastic Gradient Descent SGDRegressor 
from sklearn.linear_model import SGDRegressor
SGDreg = SGDRegressor(max_iter=1000, tol=1e-3)
SGDreg.fit (X_train, y_train)
print("Training set score SGD Regressor: {:.2f}".format(SGDreg.score(X_train, y_train)))
print("Test set score SGD Regressor: {:.2f}".format(SGDreg.score(X_test, y_test)))

#Optimizacion de hiperparámetros con Pipeline and GridSearch

param_grid = {'sgdregressor__alpha': [0.0001, 0.001, 0.01, 0.1, 10, 100],
              'sgdregressor__tol': [0.0001,0.001, 0.01, 0.1, 1, 10, 100,1000]}

# pipe = make_pipeline(MinMaxScaler(), SGDRegressor(max_iter=10000))
# pipe.get_params().keys()

# MINMAX scaler
pipe = make_pipeline(MinMaxScaler(), SGDRegressor(max_iter=10000))
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("SGDRegressor MinMax Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Standar scaler
pipe = make_pipeline(StandardScaler(), SGDRegressor(max_iter=10000))
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("SGDRegressor STANDAR Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Normalizer scaler
pipe = make_pipeline(Normalizer(), SGDRegressor(max_iter=10000))
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("SGDRegressor Normailzer Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")


# Robust scaler
pipe = make_pipeline(RobustScaler(), SGDRegressor(max_iter=10000))
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("SGDRegressor Robust Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
# print ("\n")
# Out:
# Training set score SGD Regressor: -94750015148249792957665653139963904.00
# Test set score SGD Regressor: -104167641780496975462126931616464896.00
# SGDRegressor MinMax Score without poly features: -0.08
# Best cross-validation accuracy: -2.55
# Best parameters: {'sgdregressor__alpha': 100, 'sgdregressor__tol': 0.0001}
#
#
# SGDRegressor STANDAR Score without poly features: -0.23
# Best cross-validation accuracy: -0.33
# Best parameters: {'sgdregressor__alpha': 0.0001, 'sgdregressor__tol': 0.0001}
#
#
# SGDRegressor Normailzer Score without poly features: 0.08
# Best cross-validation accuracy: -1.85
# Best parameters: {'sgdregressor__alpha': 0.0001, 'sgdregressor__tol': 0.0001}
#
#
# SGDRegressor Robust Score without poly features: 0.37
# Best cross-validation accuracy: -1.47
# Best parameters: {'sgdregressor__alpha': 10, 'sgdregressor__tol': 0.0001}

# %%
#Linear Support Vector Regression
from sklearn.svm import LinearSVR
from sklearn.svm import SVR
svr = SVR(C=16)
svr.fit(X_train, y_train)
print("Training set score: {:.2f}".format(svr.score(X_train, y_train)))
print("Test set score: {:.2f}".format(svr.score(X_test, y_test)))

param_grid = {'svr__C': [0.001, 0.01, 0.1, 1, 10, 100,1000],
              'svr__gamma': [0.0001,0.001, 0.01, 0.1, 1, 10, 100,1000]}
# pipe = make_pipeline(MinMaxScaler(), SVR())
# pipe.get_params().keys()

# MINMAX scaler
pipe = make_pipeline(MinMaxScaler(), SVR())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("SVR MinMax Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Standar scaler
pipe = make_pipeline(StandardScaler(),  SVR())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("SVR STANDAR Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Normalizer scaler
pipe = make_pipeline(Normalizer(),  SVR())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("SVR Normailzer Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")


# Robust scaler
pipe = make_pipeline(RobustScaler(),  SVR())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("SVR Robust Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")
# Out:
# Training set score: 0.77
# Test set score: -0.01
# SVR MinMax Score without poly features: 0.73
# Best cross-validation accuracy: 0.45
# Best parameters: {'svr__C': 1000, 'svr__gamma': 0.0001}
#
#
# SVR STANDAR Score without poly features: 0.76
# Best cross-validation accuracy: 0.46
# Best parameters: {'svr__C': 100, 'svr__gamma': 0.0001}
#
#
# SVR Normailzer Score without poly features: -0.03
# Best cross-validation accuracy: 0.45
# Best parameters: {'svr__C': 1000, 'svr__gamma': 0.01}
#
#
# SVR Robust Score without poly features: 0.83
# Best cross-validation accuracy: 0.47
# Best parameters: {'svr__C': 100, 'svr__gamma': 0.0001}

# %%
# Árboles de decisión regresión
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(max_depth=4)
regressor.fit(X_train, y_train)
print("Training set score: {:.2f}".format(regressor.score(X_train, y_train)))
print("Test set score: {:.2f}".format(regressor.score(X_test, y_test)))

param_grid = {'decisiontreeregressor__max_depth': [1,2,3,4,5,6,7,8],'decisiontreeregressor__min_samples_leaf': [1,2,3,4,5,6,7,8]}
# pipe = make_pipeline(MinMaxScaler(), DecisionTreeRegressor())
# pipe.get_params().keys()

# MINMAX scaler
pipe = make_pipeline(MinMaxScaler(), DecisionTreeRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" DecisionTreeRegressor MinMax Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Standar scaler
pipe = make_pipeline(StandardScaler(),  DecisionTreeRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" DecisionTreeRegressor STANDAR Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Normalizer scaler
pipe = make_pipeline(Normalizer(),  DecisionTreeRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" DecisionTreeRegressor Normailzer Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")


# Robust scaler
pipe = make_pipeline(RobustScaler(),  DecisionTreeRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" DecisionTreeRegressor Robust Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")
# Out:
# Training set score: 1.00
# Test set score: 0.85
#  DecisionTreeRegressor MinMax Score without poly features: 0.85
# Best cross-validation accuracy: 0.65
# Best parameters: {'decisiontreeregressor__max_depth': 5, 'decisiontreeregressor__min_samples_leaf': 1}
#
#
#  DecisionTreeRegressor STANDAR Score without poly features: -0.50
# Best cross-validation accuracy: 0.62
# Best parameters: {'decisiontreeregressor__max_depth': 3, 'decisiontreeregressor__min_samples_leaf': 1}
#
#
#  DecisionTreeRegressor Normailzer Score without poly features: -0.31
# Best cross-validation accuracy: 0.67
# Best parameters: {'decisiontreeregressor__max_depth': 7, 'decisiontreeregressor__min_samples_leaf': 2}
#
#
#  DecisionTreeRegressor Robust Score without poly features: 0.85
# Best cross-validation accuracy: 0.63
# Best parameters: {'decisiontreeregressor__max_depth': 3, 'decisiontreeregressor__min_samples_leaf': 1}

# %%
# Random forest regressor

from sklearn.ensemble import RandomForestRegressor
Forest = RandomForestRegressor(n_estimators=5)
Forest.fit(X_train,y_train)
print("Training set score: {:.2f}".format(Forest.score(X_train, y_train)))
print("Test set score: {:.2f}".format(Forest.score(X_test, y_test)))

# param_grid = {'randomforestregressor__max_depth': [1,2,3,4,5,6,7,8],'randomforestregressor__min_samples_leaf': [1,2,3,4,5,6,7,8],'randomforestregressor__n_estimators':[1,2,3,4,5,6]}
# param_grid = {'randomforestregressor__min_samples_leaf': [1,2,3,4,5,6,7,8],'randomforestregressor__n_estimators':[1,2,3,4,5,6]}
param_grid = {'randomforestregressor__n_estimators':[1,2,3,4,5,6]}

# pipe = make_pipeline(MinMaxScaler(), RandomForestRegressor())
# pipe.get_params().keys()

# MINMAX scaler
pipe = make_pipeline(MinMaxScaler(), RandomForestRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" RandomForestRegressor MinMax Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Standar scaler
pipe = make_pipeline(StandardScaler(),  RandomForestRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" RandomForestRegressor STANDAR Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")

# Normalizer scaler
pipe = make_pipeline(Normalizer(),  RandomForestRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" RandomForestRegressor Normailzer Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
print ("\n")


# Robust scaler
pipe = make_pipeline(RobustScaler(),  RandomForestRegressor())
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print(" RandomForestRegressor Robust Score without poly features: {:.2f}".format(grid.score(X_test, y_test)))
print("Best cross-validation accuracy: {:.2f}".format(grid.best_score_))
print("Best parameters: {}".format(grid.best_params_))
# print ("\n")
# Out:
# Training set score: 0.99
# Test set score: 0.36
#  RandomForestRegressor MinMax Score without poly features: 0.93
# Best cross-validation accuracy: 0.54
# Best parameters: {'randomforestregressor__n_estimators': 6}
#
#
#  RandomForestRegressor STANDAR Score without poly features: 0.68
# Best cross-validation accuracy: 0.72
# Best parameters: {'randomforestregressor__n_estimators': 6}
#
#
#  RandomForestRegressor Normailzer Score without poly features: 0.46
# Best cross-validation accuracy: 0.70
# Best parameters: {'randomforestregressor__n_estimators': 4}
#
#
#  RandomForestRegressor Robust Score without poly features: 0.52
# Best cross-validation accuracy: 0.58
# Best parameters: {'randomforestregressor__n_estimators': 5}
